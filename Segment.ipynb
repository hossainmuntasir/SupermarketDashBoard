# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sample = pd.read_excel("Major Assignment Superstore Data (1).xlsx","Sample")
freq = sample["Segment"].value_counts(sort = False)
print('Segment Frequency Table')
print(freq)
a = sample[sample.Segment== "Consumer"]['Segment'].count()
b = sample[sample.Segment== "Corporate"]['Segment'].count()
c = sample[sample.Segment== "Home Office"]['Segment'].count()

sns.countplot(x="Segment", data = sample)
sns.set(style = 'whitegrid', color_codes = True)
plt.title("Customer Type Column Chart", fontsize = 25, )
plt.xlabel("Customer type", fontsize = 20, color = "green")
plt.ylabel("Customer number", fontsize = 20, color = "green")
# Out:
# Segment Frequency Table
# Consumer       107
# Corporate       59
# Home Office     34
# Name: Segment, dtype: int64
# Text(0, 0.5, 'Customer number')
